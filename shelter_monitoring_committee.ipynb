# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
soup = BeautifulSoup(
    requests.get(
        'https://www.sf.gov/departments/shelter-monitoring-committee/past-meetings?page=0').text, 
        'html.parser'
    )

# %%
soup.find_all(class_="meeting-details")[0].find_all("a")
# Out:
# [<a class="inline-block font-medium mb-8 mr-8 text-title-xs" href="/meeting/may-15-2024/may-full-committee-online-meeting-access" rel="bookmark">
#  <span>May FULL COMMITTEE (Online Meeting Access)</span>
#  </a>]
